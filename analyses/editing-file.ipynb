# %%
import pandas as pd

# %%
data = pd.read_csv('FIND Survey Raw Data.csv')

# %%
data.shape
# Out:
# (3303, 125)

# %%
data.isnull()
# Out:
#          ID  Response Round  Questionnaire Version  Group  \
# 0     False           False                  False  False
# 1     False           False                  False  False
# 2     False           False                  False  False
# 3     False           False                  False  False
# 4     False           False                  False  False
# ...     ...             ...                    ...    ...
# 3298  False           False                  False  False
# 3299  False           False                  False  False
# 3300  False           False                  False  False
# 3301  False           False                  False  False
# 3302  False           False                  False  False
#
#       Myocardial InfarctionA  Myocardial InfarctionB  \
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# ...                      ...                     ...
# 3298                   False                   False
# 3299                   False                   False
# 3300                   False                   False
# 3301                   False                   False
# 3302                   False                   False
#
#       Chronic Fatigue SyndromeA  Chronic Fatigue SyndromeB  BaldnessA  \
# 0                         False                      False      False
# 1                         False                      False      False
# 2                          True                       True       True
# 3                         False                      False      False
# 4                         False                      False      False
# ...                         ...                        ...        ...
# 3298                      False                      False      False
# 3299                      False                      False      False
# 3300                      False                      False      False
# 3301                      False                      False      False
# 3302                      False                      False      False
#
#       BaldnessB  ...  Juvenile DiabetesB  MalariaA  MalariaB  \
# 0         False  ...               False     False     False
# 1         False  ...               False     False     False
# 2          True  ...               False     False     False
# 3         False  ...               False     False     False
# 4         False  ...               False     False     False
# ...         ...  ...                 ...       ...       ...
# 3298      False  ...               False     False     False
# 3299      False  ...               False     False     False
# 3300      False  ...               False     False     False
# 3301      False  ...               False     False     False
# 3302      False  ...               False     False     False
#
#       Social Anxiety DisorderA  Social Anxiety DisorderB  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 3298                     False                     False
# 3299                     False                     False
# 3300                     False                     False
# 3301                     False                     False
# 3302                     False                     False
#
#       Premature EjaculationA  Premature EjaculationB  Hip FractureA  \
# 0                      False                   False          False
# 1                      False                   False          False
# 2                      False                   False          False
# 3                      False                   False          False
# 4                      False                   False          False
# ...                      ...                     ...            ...
# 3298                   False                   False          False
# 3299                   False                   False          False
# 3300                   False                   False          False
# 3301                   False                   False          False
# 3302                   False                   False          False
#
#       Hip FractureB  Excluded_Included
# 0             False              False
# 1             False              False
# 2             False              False
# 3             False              False
# 4             False              False
# ...             ...                ...
# 3298          False              False
# 3299          False              False
# 3300          False              False
# 3301          False              False
# 3302          False              False
#
# [3303 rows x 125 columns]

# %%
data.isnull().sum()
#data[col].isnull().sum() 
#Check how many null values are in a specific column, 
#substituting the name of your column in string form 
#where it says ‘col’
# Out:
# ID                         0
# Response Round             0
# Questionnaire Version      0
# Group                      0
# Myocardial InfarctionA    32
#                           ..
# Premature EjaculationA    30
# Premature EjaculationB    47
# Hip FractureA             21
# Hip FractureB             24
# Excluded_Included          0
# Length: 125, dtype: int64

# %%
new_data = data.dropna()

# %%
new_data.isnull().sum()
# Out:
# ID                        0
# Response Round            0
# Questionnaire Version     0
# Group                     0
# Myocardial InfarctionA    0
#                          ..
# Premature EjaculationA    0
# Premature EjaculationB    0
# Hip FractureA             0
# Hip FractureB             0
# Excluded_Included         0
# Length: 125, dtype: int64

# %%
new_data.to_csv('new_data.csv',index=False)

# %%
new_data.isnull()
# Out:
#          ID  Response Round  Questionnaire Version  Group  \
# 1     False           False                  False  False
# 3     False           False                  False  False
# 5     False           False                  False  False
# 7     False           False                  False  False
# 8     False           False                  False  False
# ...     ...             ...                    ...    ...
# 3298  False           False                  False  False
# 3299  False           False                  False  False
# 3300  False           False                  False  False
# 3301  False           False                  False  False
# 3302  False           False                  False  False
#
#       Myocardial InfarctionA  Myocardial InfarctionB  \
# 1                      False                   False
# 3                      False                   False
# 5                      False                   False
# 7                      False                   False
# 8                      False                   False
# ...                      ...                     ...
# 3298                   False                   False
# 3299                   False                   False
# 3300                   False                   False
# 3301                   False                   False
# 3302                   False                   False
#
#       Chronic Fatigue SyndromeA  Chronic Fatigue SyndromeB  BaldnessA  \
# 1                         False                      False      False
# 3                         False                      False      False
# 5                         False                      False      False
# 7                         False                      False      False
# 8                         False                      False      False
# ...                         ...                        ...        ...
# 3298                      False                      False      False
# 3299                      False                      False      False
# 3300                      False                      False      False
# 3301                      False                      False      False
# 3302                      False                      False      False
#
#       BaldnessB  ...  Juvenile DiabetesB  MalariaA  MalariaB  \
# 1         False  ...               False     False     False
# 3         False  ...               False     False     False
# 5         False  ...               False     False     False
# 7         False  ...               False     False     False
# 8         False  ...               False     False     False
# ...         ...  ...                 ...       ...       ...
# 3298      False  ...               False     False     False
# 3299      False  ...               False     False     False
# 3300      False  ...               False     False     False
# 3301      False  ...               False     False     False
# 3302      False  ...               False     False     False
#
#       Social Anxiety DisorderA  Social Anxiety DisorderB  \
# 1                        False                     False
# 3                        False                     False
# 5                        False                     False
# 7                        False                     False
# 8                        False                     False
# ...                        ...                       ...
# 3298                     False                     False
# 3299                     False                     False
# 3300                     False                     False
# 3301                     False                     False
# 3302                     False                     False
#
#       Premature EjaculationA  Premature EjaculationB  Hip FractureA  \
# 1                      False                   False          False
# 3                      False                   False          False
# 5                      False                   False          False
# 7                      False                   False          False
# 8                      False                   False          False
# ...                      ...                     ...            ...
# 3298                   False                   False          False
# 3299                   False                   False          False
# 3300                   False                   False          False
# 3301                   False                   False          False
# 3302                   False                   False          False
#
#       Hip FractureB  Excluded_Included
# 1             False              False
# 3             False              False
# 5             False              False
# 7             False              False
# 8             False              False
# ...             ...                ...
# 3298          False              False
# 3299          False              False
# 3300          False              False
# 3301          False              False
# 3302          False              False
#
# [2504 rows x 125 columns]
